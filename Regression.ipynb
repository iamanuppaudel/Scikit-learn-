# %%
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\thean\\OneDrive\\Desktop\\study\\PROJECTS\\scikit-learn-videos-master\\data\\Advertising.csv', index_col=0)
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.pairplot(data, x_vars=['TV','Radio','Newspaper'], y_vars='Sales', height=7, aspect=0.5, kind='reg')

# %%
feature_cols=['TV','Radio','Newspaper']
X= data[feature_cols]

#equivalent code to above two lines
# X=data[['TV','Radio','Newspaper']]
X.head()
# Out:
#       TV  Radio  Newspaper
# 1  230.1   37.8       69.2
# 2   44.5   39.3       45.1
# 3   17.2   45.9       69.3
# 4  151.5   41.3       58.5
# 5  180.8   10.8       58.4

# %%
print (type(X))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print (X.shape)
# Out:
# (200, 3)

# %%
y= data['Sales']
y= data.Sales
y.head()
# Out:
# 1    22.1
# 2    10.4
# 3     9.3
# 4    18.5
# 5    12.9
# Name: Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print (linreg.intercept_)
print(linreg.coef_)
# Out:
# 2.8769666223179318
# [0.04656457 0.17915812 0.00345046]

# %%
zip(feature_cols,linreg.coef_)

# %%
y_pred=linreg.predict(X_test)

# %%
import numpy as np
from sklearn import metrics
print (np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 1.404651423032896
